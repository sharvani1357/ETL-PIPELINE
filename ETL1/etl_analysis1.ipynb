# %%
from supabase import create_client
import pandas as pd
import os
from dotenv import load_dotenv

# Load .env variables
load_dotenv()

# Initialize Supabase client
SUPABASE_URL = os.getenv("SUPABASE_URL")
SUPABASE_KEY = os.getenv("SUPABASE_KEY")
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

# Fetch all rows from table
response = supabase.table("telco_data").select("*").execute()

# Extract the data safely
data = response.data if hasattr(response, "data") else response.get("data")

# Convert to dataframe
df = pd.DataFrame(data)

# Show data
print(df.head())
print(df.info())
print(df.isnull().sum())
print(df.describe())
print(df.columns)
# Out:
#    id customer_id  gender  senior_citizen partner dependents  tenure  \
# 0   1        None  Female               0     Yes         No       1
# 1   2        None    Male               0      No         No      34
# 2   3        None    Male               0      No         No       2
# 3   4        None    Male               0      No         No      45
# 4   5        None  Female               0      No         No       2
#
#   phone_service multiple_lines internet_service  ... paperless_billing  \
# 0            No             No              DSL  ...               Yes
# 1           Yes             No              DSL  ...                No
# 2           Yes             No              DSL  ...               Yes
# 3            No             No              DSL  ...                No
# 4           Yes             No      Fiber optic  ...               Yes
#
#               payment_method monthly_charges total_charges churn is_senior  \
# 0           Electronic check           29.85         29.85     0         0
# 1               Mailed check           56.95       1889.50     0         0
# 2               Mailed check           53.85        108.15     1         0
# 3  Bank transfer (automatic)           42.30       1840.75     0         0
# 4           Electronic check           70.70        151.65     1         0
#
#   tenure_group services_count has_internet  monthly_total_ratio
# 0         0-12              1            1             1.000000
# 1        25-48              3            1             0.030140
# 2         0-12              3            1             0.497920
# 3        25-48              3            1             0.022980
# 4         0-12              1            1             0.466205
#
# [5 rows x 27 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1000 non-null   int64
#  1   customer_id          0 non-null      object
#  2   gender               1000 non-null   object
#  3   senior_citizen       1000 non-null   int64
#  4   partner              1000 non-null   object
#  5   dependents           1000 non-null   object
#  6   tenure               1000 non-null   int64
#  7   phone_service        1000 non-null   object
#  8   multiple_lines       1000 non-null   object
#  9   internet_service     1000 non-null   object
#  10  online_security      1000 non-null   object
#  11  online_backup        1000 non-null   object
#  12  device_protection    1000 non-null   object
#  13  tech_support         1000 non-null   object
#  14  streaming_tv         1000 non-null   object
#  15  streaming_movies     1000 non-null   object
#  16  contract             1000 non-null   object
#  17  paperless_billing    1000 non-null   object
#  18  payment_method       1000 non-null   object
#  19  monthly_charges      1000 non-null   float64
#  20  total_charges        1000 non-null   float64
#  21  churn                1000 non-null   int64
#  22  is_senior            1000 non-null   int64
#  23  tenure_group         1000 non-null   object
#  24  services_count       1000 non-null   int64
#  25  has_internet         1000 non-null   int64
#  26  monthly_total_ratio  1000 non-null   float64
# dtypes: float64(3), int64(7), object(17)
# memory usage: 211.1+ KB
# None
# id                        0
# customer_id            1000
# gender                    0
# senior_citizen            0
# partner                   0
# dependents                0
# tenure                    0
# phone_service             0
# multiple_lines            0
# internet_service          0
# online_security           0
# online_backup             0
# device_protection         0
# tech_support              0
# streaming_tv              0
# streaming_movies          0
# contract                  0
# paperless_billing         0
# payment_method            0
# monthly_charges           0
# total_charges             0
# churn                     0
# is_senior                 0
# tenure_group              0
# services_count            0
# has_internet              0
# monthly_total_ratio       0
# dtype: int64
#                 id  senior_citizen       tenure  monthly_charges  \
# count  1000.000000      1000.00000  1000.000000      1000.000000
# mean    500.500000         0.16300    32.219000        66.483800
# std     288.819436         0.36955    24.843716        29.919706
# min       1.000000         0.00000     0.000000        18.950000
# 25%     250.750000         0.00000     8.000000        42.050000
# 50%     500.500000         0.00000    29.000000        74.250000
# 75%     750.250000         0.00000    56.000000        90.050000
# max    1000.000000         1.00000    72.000000       116.250000
#
#        total_charges       churn   is_senior  services_count  has_internet  \
# count    1000.000000  1000.00000  1000.00000     1000.000000   1000.000000
# mean     2332.048400     0.25600     0.16300        3.451000      0.797000
# std      2288.055287     0.43664     0.36955        2.072654      0.402434
# min         0.000000     0.00000     0.00000        0.000000      0.000000
# 25%       384.975000     0.00000     0.00000        2.000000      1.000000
# 50%      1448.875000     0.00000     0.00000        3.000000      1.000000
# 75%      3942.400000     1.00000     0.00000        5.000000      1.000000
# max      8476.500000     1.00000     1.00000        8.000000      1.000000
#
#        monthly_total_ratio
# count          1000.000000
# mean              0.161468
# std               0.283609
# min               0.000000
# 25%               0.017748
# 50%               0.034581
# 75%               0.118073
# max               1.000000
# Index(['id', 'customer_id', 'gender', 'senior_citizen', 'partner',
#        'dependents', 'tenure', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'contract', 'paperless_billing', 'payment_method', 'monthly_charges',
#        'total_charges', 'churn', 'is_senior', 'tenure_group', 'services_count',
#        'has_internet', 'monthly_total_ratio'],
#       dtype='object')
